# %% [markdown]
# # Task 10 — Dockerfile
#
# **Wave 3** · part of the *image photo-z backend* (`tasks-2026-6-17`).
#
# This task pack builds the **image photo-z FastAPI backend**. A placeholder model (`models/fake_image_model.pkl`, 64×64×5 image → random z) lets you build & test the whole API before the real CNN exists. Workflow per task: **develop + test the piece in this notebook → move the working code into the matching `backend/*.py` → run the check → commit & push.**

# %% [markdown]
# ## ⚠️ Dependency
#
# This task builds on **Task 06** and **Task 08**. Make sure it is **done and merged into `2026.6.17`** first (or coordinate with its owner / just wait).

# %% [markdown]
# ## 🧭 Setup (run first)

# %%
# --- run this FIRST: hop to the repo root + fetch the placeholder model from GCS ---
import os, sys
d = os.getcwd()
while not os.path.isdir(os.path.join(d, 'backend')) and d != os.path.dirname(d):
    d = os.path.dirname(d)
os.chdir(d); sys.path.insert(0, d)
print('repo root:', d)
# the placeholder model is NOT in git — pull it from GCS (needs gcloud auth, see README)
if not os.path.exists('models/fake_image_model.pkl'):
    os.makedirs('models', exist_ok=True)
    # !gcloud storage cp gs://macrocosm-lewagon/models/fake_image_model.pkl models/fake_image_model.pkl

# %% [markdown]
# ## 🎯 What to build
#
# Write `backend/Dockerfile`: base `python:3.10-slim`, install `backend/requirements.txt`, copy `backend/` and `models/fake_image_model.pkl`, set `MODEL_PATH`, run `uvicorn backend.main:app` on `0.0.0.0:8000`.
#
# **Target file:** `backend/Dockerfile`

# %% [markdown]
# ## 🛠️ Develop & test here first

# %%
# TODO: complete the Dockerfile, then paste it into backend/Dockerfile.
dockerfile = """FROM python:3.10-slim
# TODO WORKDIR /app
# TODO COPY backend/requirements.txt ; pip install -r requirements.txt
# TODO COPY backend/  and  models/fake_image_model.pkl
# TODO ENV MODEL_PATH=models/fake_image_model.pkl
# TODO EXPOSE 8000 ; CMD ["uvicorn","backend.main:app","--host","0.0.0.0","--port","8000"]
"""
print(dockerfile)

# %% [markdown]
# ## 📦 Move it into `backend/Dockerfile`
# Paste your working code into the matching spot in `backend/Dockerfile` (replace the `# TODO`). Then run the check below.

# %% [markdown]
# ## ✅ Check (after moving it into the backend)

# %%
df=open('backend/Dockerfile').read()
assert 'uvicorn' in df and 'python:3.10' in df; print('OK')

# %%
# === Commit & push on YOUR OWN branch (run last; repo root after Setup) ===
# 04+07 share model.py and 05+08 share main.py — pushing straight to 2026.6.17
# would clobber a teammate. So each task pushes its own branch; open a PR after.
# !git checkout -B task/10-dockerfile
# !git add backend/Dockerfile notebooks/tasks-2026-6-17/10-dockerfile/task.ipynb
# !git commit -m "dockerfile task"
# !git push -u origin task/10-dockerfile
# then merge it back into 2026.6.17 -> see MERGE.md in this folder

# %% [markdown]
# ## 🔭 Go further (optional)
# Play with edge cases, add a docstring or a small test, and if you find a cleaner way or a bug, post it to our YouTrack Knowledge Base.
