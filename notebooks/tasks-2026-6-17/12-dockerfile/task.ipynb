# %% [markdown]
# # Task 12 — Dockerfile
#
# **Wave 3** · target file: `backend/Dockerfile` · prerequisites: task 08, task 10
#
# **🎯 Goal:** Containerize the API (bakes in both model artifacts).
#
# Part of the *2026-06-17 fused photo-z backend*. Plan & deps: `../PLAN.md` · conventions: `../README.md`.

# %%
# === Setup: run me first. Hops to the repo root so `import backend` and models/ resolve,
# and pulls the model artifact(s) from GCS if missing (needs gcloud auth - see README). ===
import os, sys
p = os.path.abspath('.')
while p != '/' and not (os.path.isdir(p+'/backend') and os.path.isdir(p+'/notebooks')):
    p = os.path.dirname(p)
os.chdir(p); sys.path.insert(0, p)
print('repo root:', p)
os.makedirs('models', exist_ok=True)
if not os.path.exists('models/fake_image_model.pkl'):
    os.system('gcloud storage cp gs://macrocosm-lewagon/models/fake_image_model.pkl models/fake_image_model.pkl')
print('models:', [f for f in os.listdir('models') if f.endswith('.pkl')])

# %% [markdown]
# ## What to build
# Complete `backend/Dockerfile`: a slim python base, `WORKDIR /app`, copy+install
# `backend/requirements.txt`, copy `backend/` and **both** `models/*.pkl`, set
# `BASELINE_PATH`/`IMAGE_MODEL_PATH`, `EXPOSE 8000`, and `CMD uvicorn backend.main:app --host 0.0.0.0 --port 8000`.

# %% [markdown]
# ## 🛠️ Develop & test here first
# Fill the `# TODO` so the asserts pass. **Don't** paste the answer — write it.

# %%
dockerfile = """FROM python:3.12-slim
# TODO WORKDIR /app
# TODO COPY backend/requirements.txt ; RUN pip install -r requirements.txt
# TODO COPY backend/  and  models/baseline_stack.pkl  and  models/fake_image_model.pkl
# TODO ENV BASELINE_PATH=models/baseline_stack.pkl IMAGE_MODEL_PATH=models/fake_image_model.pkl
# TODO EXPOSE 8000 ; CMD ["uvicorn","backend.main:app","--host","0.0.0.0","--port","8000"]
"""
print(dockerfile)   # complete it, then paste into backend/Dockerfile

# %% [markdown]
# ## ➡️ Move it into `backend/Dockerfile`
# Once the cell above passes, put your implementation into **`backend/Dockerfile`** (replace the `# TODO`). Then run the **Check** cell — it imports from `backend/` and verifies the real module.

# %% [markdown]
# ## ✅ Check (imports from `backend/`)

# %%
t = open("backend/Dockerfile").read()
for k in ["FROM", "backend/requirements", "pip install", "COPY backend/", "baseline_stack.pkl",
          "fake_image_model.pkl", "uvicorn", "backend.main:app"]:
    assert k in t, f"Dockerfile missing: {k}"
print("Dockerfile OK")

# %% [markdown]
# > 💬 *Discuss freely with the team; post anything useful to the Knowledge Base.*

# %% [markdown]
# ## 🚀 Ship it

# %%
# === Commit & push on YOUR OWN branch (run last; repo root after Setup) ===
# !git checkout -B task/12-dockerfile
# !git add backend/Dockerfile notebooks/tasks-2026-6-17/12-dockerfile/task.ipynb
# !git commit -m "12-dockerfile: Dockerfile"
# !git push -u origin task/12-dockerfile
# then merge back into 2026.6.17 -> see MERGE.md in this folder
