# %% [markdown]
# # Task 02 — Request / response schemas
#
# **Wave 1** · part of the *image photo-z backend* (`tasks-2026-6-17`).
#
# This task pack builds the **image photo-z FastAPI backend**. A placeholder model (`models/fake_image_model.pkl`, 64×64×5 image → random z) lets you build & test the whole API before the real CNN exists. Workflow per task: **develop + test the piece in this notebook → move the working code into the matching `backend/*.py` → run the check → commit & push.**

# %% [markdown]
# ## 🧭 Setup (run first)

# %%
# --- run this FIRST: hop to the repo root + fetch the placeholder model from GCS ---
import os, sys
d = os.getcwd()
while not os.path.isdir(os.path.join(d, 'backend')) and d != os.path.dirname(d):
    d = os.path.dirname(d)
os.chdir(d); sys.path.insert(0, d)
print('repo root:', d)
# the placeholder model is NOT in git — pull it from GCS (needs gcloud auth, see README)
if not os.path.exists('models/fake_image_model.pkl'):
    os.makedirs('models', exist_ok=True)
    # !gcloud storage cp gs://macrocosm-lewagon/models/fake_image_model.pkl models/fake_image_model.pkl

# %% [markdown]
# ## 🎯 What to build
#
# Define 3 Pydantic models in `backend/schemas.py`: `PredictRequest(images=...)` (a batch of 64×64×5 cutouts, i.e. a nested list shaped (n,64,64,5)), `Prediction(z_pred: float)`, `PredictResponse(model: str, n: int, predictions: List[Prediction])`.
#
# **Target file:** `backend/schemas.py`

# %% [markdown]
# ## 🛠️ Develop & test here first

# %%
import numpy as np
from typing import List
from pydantic import BaseModel, Field
# TODO: define PredictRequest(images=...), Prediction(z_pred: float),
#       PredictResponse(model: str, n: int, predictions: List[Prediction])

# make this pass once your classes exist, then paste into backend/schemas.py:
req  = PredictRequest(images=np.zeros((1, 64, 64, 5)).tolist())
resp = PredictResponse(model="fake", n=1, predictions=[Prediction(z_pred=0.1)])
assert resp.n == 1 and resp.predictions[0].z_pred == 0.1
print("OK")

# %% [markdown]
# ## 📦 Move it into `backend/schemas.py`
# Paste your working code into the matching spot in `backend/schemas.py` (replace the `# TODO`). Then run the check below.

# %% [markdown]
# ## ✅ Check (after moving it into the backend)

# %%
from backend.schemas import PredictRequest, PredictResponse, Prediction
print('OK', [m.__name__ for m in (PredictRequest,Prediction,PredictResponse)])

# %%
# === Commit & push on YOUR OWN branch (run last; repo root after Setup) ===
# 04+07 share model.py and 05+08 share main.py — pushing straight to 2026.6.17
# would clobber a teammate. So each task pushes its own branch; open a PR after.
# !git checkout -B task/02-schemas
# !git add backend/schemas.py notebooks/tasks-2026-6-17/02-schemas/task.ipynb
# !git commit -m "schemas task"
# !git push -u origin task/02-schemas
# then merge it back into 2026.6.17 -> see MERGE.md in this folder

# %% [markdown]
# ## 🔭 Go further (optional)
# Play with edge cases, add a docstring or a small test, and if you find a cleaner way or a bug, post it to our YouTrack Knowledge Base.
