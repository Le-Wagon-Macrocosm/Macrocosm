# %% [markdown]
# # Task 08 — POST /predict
#
# **Wave 2** · part of the *image photo-z backend* (`tasks-2026-6-17`).
#
# This task pack builds the **image photo-z FastAPI backend**. A placeholder model (`models/fake_image_model.pkl`, 64×64×5 image → random z) lets you build & test the whole API before the real CNN exists. Workflow per task: **develop + test the piece in this notebook → move the working code into the matching `backend/*.py` → run the check → commit & push.**

# %% [markdown]
# ## ⚠️ Dependency
#
# This task builds on **Task 02** and **Task 03** and **Task 07**. Make sure it is **done and merged into `2026.6.17`** first (or coordinate with its owner / just wait).

# %% [markdown]
# ## 🧭 Setup (run first)

# %%
# --- run this FIRST: hop to the repo root + fetch the placeholder model from GCS ---
import os, sys
d = os.getcwd()
while not os.path.isdir(os.path.join(d, 'backend')) and d != os.path.dirname(d):
    d = os.path.dirname(d)
os.chdir(d); sys.path.insert(0, d)
print('repo root:', d)
# the placeholder model is NOT in git — pull it from GCS (needs gcloud auth, see README)
if not os.path.exists('models/fake_image_model.pkl'):
    os.makedirs('models', exist_ok=True)
    # !gcloud storage cp gs://macrocosm-lewagon/models/fake_image_model.pkl models/fake_image_model.pkl

# %% [markdown]
# ## 🎯 What to build
#
# Add **`POST /predict`** to `backend/main.py`: take a `PredictRequest`, run `prepare_images` then `predict_z`, return a `PredictResponse`. On `ValueError` from preprocessing, raise `HTTPException(status_code=422, detail=str(e))`.
#
# **Target file:** `backend/main.py`

# %% [markdown]
# ## 🛠️ Develop & test here first

# %%
# You will add POST /predict to backend/main.py. Your handler should:
#   - take a PredictRequest
#   - call prepare_images(req.images), wrapping ValueError -> HTTPException(status_code=422, ...)
#   - call predict_z(arr)
#   - return PredictResponse(model=..., n=len(z), predictions=[Prediction(z_pred=v) for v in z])
# TODO: implement it in backend/main.py, then run the Check cell.
print("plan ready -> implement POST /predict in backend/main.py")

# %% [markdown]
# ## 📦 Move it into `backend/main.py`
# Paste your working code into the matching spot in `backend/main.py` (replace the `# TODO`). Then run the check below.

# %% [markdown]
# ## ✅ Check (after moving it into the backend)

# %%
import numpy as np
from fastapi.testclient import TestClient
from backend.main import app
r=TestClient(app).post('/predict', json={'images': np.zeros((3,64,64,5)).tolist()})
print(r.status_code); print(r.json()['n'], 'predictions')

# %%
# === Commit & push on YOUR OWN branch (run last; repo root after Setup) ===
# 04+07 share model.py and 05+08 share main.py — pushing straight to 2026.6.17
# would clobber a teammate. So each task pushes its own branch; open a PR after.
# !git checkout -B task/08-predict-endpoint
# !git add backend/main.py notebooks/tasks-2026-6-17/08-predict-endpoint/task.ipynb
# !git commit -m "predict-endpoint task"
# !git push -u origin task/08-predict-endpoint
# then merge it back into 2026.6.17 -> see MERGE.md in this folder

# %% [markdown]
# ## 🔭 Go further (optional)
# Play with edge cases, add a docstring or a small test, and if you find a cleaner way or a bug, post it to our YouTrack Knowledge Base.
