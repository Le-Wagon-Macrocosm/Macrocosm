# %% [markdown]
# # Task 03 — Image preprocessing
#
# **Wave 1** · part of the *image photo-z backend* (`tasks-2026-6-17`).
#
# This task pack builds the **image photo-z FastAPI backend**. A placeholder model (`models/fake_image_model.pkl`, 64×64×5 image → random z) lets you build & test the whole API before the real CNN exists. Workflow per task: **develop + test the piece in this notebook → move the working code into the matching `backend/*.py` → run the check → commit & push.**

# %% [markdown]
# ## 🧭 Setup (run first)

# %%
# --- run this FIRST: hop to the repo root + fetch the placeholder model from GCS ---
import os, sys
d = os.getcwd()
while not os.path.isdir(os.path.join(d, 'backend')) and d != os.path.dirname(d):
    d = os.path.dirname(d)
os.chdir(d); sys.path.insert(0, d)
print('repo root:', d)
# the placeholder model is NOT in git — pull it from GCS (needs gcloud auth, see README)
if not os.path.exists('models/fake_image_model.pkl'):
    os.makedirs('models', exist_ok=True)
    # !gcloud storage cp gs://macrocosm-lewagon/models/fake_image_model.pkl models/fake_image_model.pkl

# %% [markdown]
# ## 🎯 What to build
#
# Implement `prepare_images(images) -> np.ndarray` in `backend/preprocessing.py`: turn the raw payload into a float32 `(n,64,64,5)` array. Accept a single `(64,64,5)` image or a batch; **raise ValueError** on wrong shape or empty batch.
#
# **Target file:** `backend/preprocessing.py`

# %% [markdown]
# ## 🛠️ Develop & test here first

# %%
import numpy as np
IMG_SHAPE = (64, 64, 5)
def prepare_images(images):
    # TODO: np.asarray(float32); a single (64,64,5) -> batch of 1;
    #       validate ndim==4 and shape[1:]==IMG_SHAPE; raise ValueError on bad shape / empty
    raise NotImplementedError

# make all three pass, then paste prepare_images into backend/preprocessing.py:
assert prepare_images(np.zeros((64, 64, 5))).shape == (1, 64, 64, 5)
assert prepare_images(np.zeros((3, 64, 64, 5))).shape == (3, 64, 64, 5)
try:
    prepare_images(np.zeros((1, 32, 32, 5))); print("FAIL: should have raised")
except ValueError:
    print("OK: bad shape raises")

# %% [markdown]
# ## 📦 Move it into `backend/preprocessing.py`
# Paste your working code into the matching spot in `backend/preprocessing.py` (replace the `# TODO`). Then run the check below.

# %% [markdown]
# ## ✅ Check (after moving it into the backend)

# %%
import numpy as np
from backend.preprocessing import prepare_images
assert prepare_images(np.zeros((2,64,64,5))).shape==(2,64,64,5); print('OK')

# %%
# === Commit & push on YOUR OWN branch (run last; repo root after Setup) ===
# 04+07 share model.py and 05+08 share main.py — pushing straight to 2026.6.17
# would clobber a teammate. So each task pushes its own branch; open a PR after.
# !git checkout -B task/03-preprocessing
# !git add backend/preprocessing.py notebooks/tasks-2026-6-17/03-preprocessing/task.ipynb
# !git commit -m "preprocessing task"
# !git push -u origin task/03-preprocessing
# then merge it back into 2026.6.17 -> see MERGE.md in this folder

# %% [markdown]
# ## 🔭 Go further (optional)
# Play with edge cases, add a docstring or a small test, and if you find a cleaner way or a bug, post it to our YouTrack Knowledge Base.
