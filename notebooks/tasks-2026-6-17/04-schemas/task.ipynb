# %% [markdown]
# # Task 04 — Schemas
#
# **Wave 1** · target file: `backend/schemas.py` · prerequisites: none
#
# **🎯 Goal:** Pydantic `TabularInput` + `PredictResponse`.
#
# Part of the *2026-06-17 fused photo-z backend*. Plan & deps: `../PLAN.md` · conventions: `../README.md`.

# %%
# === Setup: run me first. Hops to the repo root so `import backend` and models/ resolve,
# and pulls the model artifact(s) from GCS if missing (needs gcloud auth - see README). ===
import os, sys
p = os.path.abspath('.')
while p != '/' and not (os.path.isdir(p+'/backend') and os.path.isdir(p+'/notebooks')):
    p = os.path.dirname(p)
os.chdir(p); sys.path.insert(0, p)
print('repo root:', p)
os.makedirs('models', exist_ok=True)
if not os.path.exists('models/fake_image_model.pkl'):
    os.system('gcloud storage cp gs://macrocosm-lewagon/models/fake_image_model.pkl models/fake_image_model.pkl')
print('models:', [f for f in os.listdir('models') if f.endswith('.pkl')])

# %% [markdown]
# ## What to build
# In `backend/schemas.py`:
# - **`TabularInput`** — one `Optional[float] = None` field per raw catalog column
#   (`dered_u..z`, `expRad_r`, `deVRad_r`, `petroRad_r`, `petroR50_r`, `petroR90_r`, `fracDeV_r`).
# - **`PredictResponse`** — `z: float`; `distance_gly`, `z_lo`, `z_hi`: `Optional[float] = None`.

# %% [markdown]
# ## 🛠️ Develop & test here first
# Fill the `# TODO` so the asserts pass. **Don't** paste the answer — write it.

# %%
from typing import Optional
from pydantic import BaseModel
# TODO: define TabularInput and PredictResponse per the spec.

t = TabularInput(dered_r=17.5)
assert t.dered_r == 17.5 and t.petroR90_r is None
r = PredictResponse(z=0.1, distance_gly=1.5)
assert r.z == 0.1 and r.z_lo is None
print("OK")

# %% [markdown]
# ## ➡️ Move it into `backend/schemas.py`
# Once the cell above passes, put your implementation into **`backend/schemas.py`** (replace the `# TODO`). Then run the **Check** cell — it imports from `backend/` and verifies the real module.

# %% [markdown]
# ## ✅ Check (imports from `backend/`)

# %%
import importlib, backend.schemas as S; importlib.reload(S)
r = S.PredictResponse(z=0.2)
assert r.z == 0.2 and r.distance_gly is None
assert S.TabularInput(petroR50_r=1.5).petroR50_r == 1.5
print("schemas OK")

# %% [markdown]
# > 💬 *Discuss freely with the team; post anything useful to the Knowledge Base.*

# %% [markdown]
# ## 🚀 Ship it

# %%
# === Commit & push on YOUR OWN branch (run last; repo root after Setup) ===
# !git checkout -B task/04-schemas
# !git add backend/schemas.py notebooks/tasks-2026-6-17/04-schemas/task.ipynb
# !git commit -m "04-schemas: Schemas"
# !git push -u origin task/04-schemas
# then merge back into 2026.6.17 -> see MERGE.md in this folder
